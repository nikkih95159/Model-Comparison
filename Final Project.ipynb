# %%
import scipy.io as sio
import numpy as np
import operator
import pandas as pd
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn import tree
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Spambase Data

# %%
spambase = pd.read_csv("spambase.data", sep=",", header=None)
print(spambase.shape)

#shuffle spam data - Trial 1
spambase = spambase.sample(frac=1).reset_index(drop=True)
spamData = spambase.values
spamX = spamData[:,:-1]
spamY = spamData[:,-1]

# 20/80
spamX_train1_20  = spamX[:int(0.2*len(spamX))]
spamX_test1_20 = spamX[int(0.2*len(spamX)):]     
spamY_train1_20 = spamY[:int(spamX.shape[0]*0.2)]
spamY_test1_20 = spamY[int(spamX.shape[0]*0.2):]

# # 50/50
spamX_train1_50  = spamX[:int(spamX.shape[0]*0.5),:]
spamX_test1_50 = spamX[int(spamX.shape[0]*0.5):,:]     
spamY_train1_50 = spamY[:int(spamX.shape[0]*0.5)]
spamY_test1_50 = spamY[int(spamX.shape[0]*0.5):]

# # 80/20
spamX_train1_80  = spamX[:int(spamX.shape[0]*0.8),:]
spamX_test1_80 = spamX[int(spamX.shape[0]*0.8):,:]     
spamY_train1_80 = spamY[:int(spamX.shape[0]*0.8)]
spamY_test1_80 = spamY[int(spamX.shape[0]*0.8):]

#shuffle spam data - Trial 2
spambase = spambase.sample(frac=1).reset_index(drop=True)
spamData = spambase.values
spamX = spamData[:,:-1]
spamY = spamData[:,-1]

# 20/80
spamX_train2_20  = spamX[:int(spamX.shape[0]*0.2),:]
spamX_test2_20 = spamX[int(spamX.shape[0]*0.2):,:]     
spamY_train2_20 = spamY[:int(spamX.shape[0]*0.2)]
spamY_test2_20 = spamY[int(spamX.shape[0]*0.2):]

# # 50/50
spamX_train2_50  = spamX[:int(spamX.shape[0]*0.5),:]
spamX_test2_50 = spamX[int(spamX.shape[0]*0.5):,:]     
spamY_train2_50 = spamY[:int(spamX.shape[0]*0.5)]
spamY_test2_50 = spamY[int(spamX.shape[0]*0.5):]

# # 80/20
spamX_train2_80  = spamX[:int(spamX.shape[0]*0.8),:]
spamX_test2_80 = spamX[int(spamX.shape[0]*0.8):,:]     
spamY_train2_80 = spamY[:int(spamX.shape[0]*0.8)]
spamY_test2_80 = spamY[int(spamX.shape[0]*0.8):]

#shuffle spam data - Trial 3
spambase = spambase.sample(frac=1).reset_index(drop=True)
spamData = spambase.values
spamX = spamData[:,:-1]
spamY = spamData[:,-1]

# 20/80
spamX_train3_20  = spamX[:int(spamX.shape[0]*0.2),:]
spamX_test3_20 = spamX[int(spamX.shape[0]*0.2):,:]     
spamY_train3_20 = spamY[:int(spamX.shape[0]*0.2)]
spamY_test3_20 = spamY[int(spamX.shape[0]*0.2):]

# # 50/50
spamX_train3_50  = spamX[:int(spamX.shape[0]*0.5),:]
spamX_test3_50 = spamX[int(spamX.shape[0]*0.5):,:]     
spamY_train3_50 = spamY[:int(spamX.shape[0]*0.5)]
spamY_test3_50 = spamY[int(spamX.shape[0]*0.5):]

# # 80/20
spamX_train3_80  = spamX[:int(spamX.shape[0]*0.8),:]
spamX_test3_80 = spamX[int(spamX.shape[0]*0.8):,:]     
spamY_train3_80 = spamY[:int(spamX.shape[0]*0.8)]
spamY_test3_80 = spamY[int(spamX.shape[0]*0.8):]
# Out:
# (4601, 58)

# %% [markdown]
# ## Online Shoppers Data

# %%
shoppers = pd.read_csv("shoppers.csv", header=None)

print(shoppers.shape)
#shuffle shoppers data - Trial 1
shoppers = shoppers.sample(frac=1).reset_index(drop=True)
shoppersData = shoppers.values
shoppersX = shoppersData[:,:-1]
shoppersY = shoppersData[:,-1]

# 20/80
shoppersX_train1_20  = shoppersX[:int(shoppersX.shape[0]*0.2),:]
shoppersX_test1_20 = shoppersX[int(shoppersX.shape[0]*0.2):,:]     
shoppersY_train1_20 = shoppersY[:int(shoppersX.shape[0]*0.2)]
shoppersY_test1_20 = shoppersY[int(shoppersX.shape[0]*0.2):]

# 50/50
shoppersX_train1_50  = shoppersX[:int(shoppersX.shape[0]*0.5),:]
shoppersX_test1_50 = shoppersX[int(shoppersX.shape[0]*0.5):,:]     
shoppersY_train1_50 = shoppersY[:int(shoppersX.shape[0]*0.5)]
shoppersY_test1_50 = shoppersY[int(shoppersX.shape[0]*0.5):]

# 80/20
shoppersX_train1_80  = shoppersX[:int(shoppersX.shape[0]*0.8),:]
shoppersX_test1_80 = shoppersX[int(shoppersX.shape[0]*0.8):,:]     
shoppersY_train1_80 = shoppersY[:int(shoppersX.shape[0]*0.8)]
shoppersY_test1_80 = shoppersY[int(shoppersX.shape[0]*0.8):]

# shuffle spam data - Trial 2
shoppers = shoppers.sample(frac=1).reset_index(drop=True)
shoppersData = shoppers.values
shoppersX = shoppersData[:,:-1]
shoppersY = shoppersData[:,-1]

# 20/80
shoppersX_train2_20  = shoppersX[:int(shoppersX.shape[0]*0.2),:]
shoppersX_test2_20 = shoppersX[int(shoppersX.shape[0]*0.2):,:]     
shoppersY_train2_20 = shoppersY[:int(shoppersX.shape[0]*0.2)]
shoppersY_test2_20 = shoppersY[int(shoppersX.shape[0]*0.2):]

# 50/50
shoppersX_train2_50  = shoppersX[:int(shoppersX.shape[0]*0.5),:]
shoppersX_test2_50 = shoppersX[int(shoppersX.shape[0]*0.5):,:]     
shoppersY_train2_50 = shoppersY[:int(shoppersX.shape[0]*0.5)]
shoppersY_test2_50 = shoppersY[int(shoppersX.shape[0]*0.5):]

# 80/20
shoppersX_train2_80  = shoppersX[:int(shoppersX.shape[0]*0.8),:]
shoppersX_test2_80 = shoppersX[int(shoppersX.shape[0]*0.8):,:]     
shoppersY_train2_80 = shoppersY[:int(shoppersX.shape[0]*0.8)]
shoppersY_test2_80 = shoppersY[int(shoppersX.shape[0]*0.8):]

#shuffle spam data - Trial 3
shoppers = shoppers.sample(frac=1).reset_index(drop=True)
shoppersData = shoppers.values
shoppersX = shoppersData[:,:-1]
shoppersY = shoppersData[:,-1]

# 20/80
shoppersX_train3_20  = shoppersX[:int(shoppersX.shape[0]*0.2),:]
shoppersX_test3_20 = shoppersX[int(shoppersX.shape[0]*0.2):,:]     
shoppersY_train3_20 = shoppersY[:int(shoppersX.shape[0]*0.2)]
shoppersY_test3_20 = shoppersY[int(shoppersX.shape[0]*0.2):]

# 50/50
shoppersX_train3_50  = shoppersX[:int(shoppersX.shape[0]*0.5),:]
shoppersX_test3_50 = shoppersX[int(shoppersX.shape[0]*0.5):,:]     
shoppersY_train3_50 = shoppersY[:int(shoppersX.shape[0]*0.5)]
shoppersY_test3_50 = shoppersY[int(shoppersX.shape[0]*0.5):]

# 80/20
shoppersX_train3_80  = shoppersX[:int(shoppersX.shape[0]*0.8),:]
shoppersX_test3_80 = shoppersX[int(shoppersX.shape[0]*0.8):,:]     
shoppersY_train3_80 = shoppersY[:int(shoppersX.shape[0]*0.8)]
shoppersY_test3_80 = shoppersY[int(shoppersX.shape[0]*0.8):]
# Out:
# (12330, 30)

# %% [markdown]
# ## Eletrical Grid Stability Stimulated Data

# %%
elecgrid = pd.read_csv("electrical grid.csv", header=None)

print(elecgrid.shape)
#shuffle elecgrid data - Trial 1
elecgrid = elecgrid.sample(frac=1).reset_index(drop=True)
elecgridData = elecgrid.values

elecgridX = elecgridData[:,:-1]
elecgridY = elecgridData[:,-1]

# 20/80
elecgridX_train1_20  = elecgridX[:int(elecgridX.shape[0]*0.2),:]
elecgridX_test1_20 = elecgridX[int(elecgridX.shape[0]*0.2):,:]     
elecgridY_train1_20 = elecgridY[:int(elecgridX.shape[0]*0.2)]
elecgridY_test1_20 = elecgridY[int(elecgridX.shape[0]*0.2):]

# 50/50
elecgridX_train1_50  = elecgridX[:int(elecgridX.shape[0]*0.5),:]
elecgridX_test1_50 = elecgridX[int(elecgridX.shape[0]*0.5):,:]     
elecgridY_train1_50 = elecgridY[:int(elecgridX.shape[0]*0.5)]
elecgridY_test1_50 = elecgridY[int(elecgridX.shape[0]*0.5):]

# 80/20
elecgridX_train1_80  = elecgridX[:int(elecgridX.shape[0]*0.8),:]
elecgridX_test1_80 = elecgridX[int(elecgridX.shape[0]*0.8):,:]     
elecgridY_train1_80 = elecgridY[:int(elecgridX.shape[0]*0.8)]
elecgridY_test1_80 = elecgridY[int(elecgridX.shape[0]*0.8):]

# shuffle spam data - Trial 2
elecgrid = elecgrid.sample(frac=1).reset_index(drop=True)
elecgridData = elecgrid.values

elecgridX = elecgridData[:,:-1]
elecgridY = elecgridData[:,-1]

# 20/80
elecgridX_train2_20  = elecgridX[:int(elecgridX.shape[0]*0.2),:]
elecgridX_test2_20 = elecgridX[int(elecgridX.shape[0]*0.2):,:]     
elecgridY_train2_20 = elecgridY[:int(elecgridX.shape[0]*0.2)]
elecgridY_test2_20 = elecgridY[int(elecgridX.shape[0]*0.2):]

# 50/50
elecgridX_train2_50  = elecgridX[:int(elecgridX.shape[0]*0.5),:]
elecgridX_test2_50 = elecgridX[int(elecgridX.shape[0]*0.5):,:]     
elecgridY_train2_50 = elecgridY[:int(elecgridX.shape[0]*0.5)]
elecgridY_test2_50 = elecgridY[int(elecgridX.shape[0]*0.5):]

# 80/20
elecgridX_train2_80  = elecgridX[:int(elecgridX.shape[0]*0.8),:]
elecgridX_test2_80 = elecgridX[int(elecgridX.shape[0]*0.8):,:]     
elecgridY_train2_80 = elecgridY[:int(elecgridX.shape[0]*0.8)]
elecgridY_test2_80 = elecgridY[int(elecgridX.shape[0]*0.8):]

#shuffle spam data - Trial 3
elecgrid = elecgrid.sample(frac=1).reset_index(drop=True)
elecgridData = elecgrid.values

elecgridX = elecgridData[:,:-1]
elecgridY = elecgridData[:,-1]

# 20/80
elecgridX_train3_20  = elecgridX[:int(elecgridX.shape[0]*0.2),:]
elecgridX_test3_20 = elecgridX[int(elecgridX.shape[0]*0.2):,:]     
elecgridY_train3_20 = elecgridY[:int(elecgridX.shape[0]*0.2)]
elecgridY_test3_20 = elecgridY[int(elecgridX.shape[0]*0.2):]

# 50/50
elecgridX_train3_50  = elecgridX[:int(elecgridX.shape[0]*0.5),:]
elecgridX_test3_50 = elecgridX[int(elecgridX.shape[0]*0.5):,:]     
elecgridY_train3_50 = elecgridY[:int(elecgridX.shape[0]*0.5)]
elecgridY_test3_50 = elecgridY[int(elecgridX.shape[0]*0.5):]

# 80/20
elecgridX_train3_80  = elecgridX[:int(elecgridX.shape[0]*0.8),:]
elecgridX_test3_80 = elecgridX[int(elecgridX.shape[0]*0.8):,:]     
elecgridY_train3_80 = elecgridY[:int(elecgridX.shape[0]*0.8)]
elecgridY_test3_80 = elecgridY[int(elecgridX.shape[0]*0.8):]
# Out:
# (10000, 14)

# %% [markdown]
# ## SVM Classifier

# %%
classifier = svm.SVC(kernel = 'rbf')

# %%
## Spambase Data

grid = GridSearchCV(classifier, [{'C':[100],'gamma':[10e-4]}], n_jobs = -1, cv = 3, return_train_score= True, iid = True)

print('\033[1m' + 'Spambase Data' + '\033[0m')
print('Partition for 20/80')
print('Best C: 100, Best gamma: 10e-4')
# spam 20/80 1st trial
grid.fit(spamX_train1_20, spamY_train1_20)
spam_train1_acc_20_svm = grid.cv_results_['mean_train_score'][0]
spam_val1_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_20_svm, ', Validation Accuracy: ', spam_val1_acc_20_svm)
spamY_pred1_20 = grid.predict(spamX_test1_20)
spam_test1_acc_20_svm = (np.sum(spamY_pred1_20 == spamY_test1_20) / len(spamY_test1_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_20_svm)

#spam 20/80 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train2_20, spamY_train2_20)
spam_train2_acc_20_svm = grid.cv_results_['mean_train_score'][0]
spam_val2_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_20_svm, ', Validation Accuracy: ', spam_val2_acc_20_svm)
spamY_pred2_20 = grid.predict(spamX_test2_20)
spam_test2_acc_20_svm = (np.sum(spamY_pred2_20 == spamY_test2_20) / len(spamY_test2_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_20_svm)

#spam 20/80 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train3_20, spamY_train3_20)
spam_train3_acc_20_svm = grid.cv_results_['mean_train_score'][0]
spam_val3_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_20_svm, ', Validation Accuracy: ', spam_val3_acc_20_svm)
spamY_pred3_20 = grid.predict(spamX_test3_20)
spam_test3_acc_20_svm = (np.sum(spamY_pred3_20 == spamY_test3_20) / len(spamY_test3_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_20_svm)
_
print()
print('Partition for 50/50')
# spam 50/50 1st trial
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train1_50, spamY_train1_50)
spam_train1_acc_50_svm = grid.cv_results_['mean_train_score'][0]
spam_val1_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_50_svm, ', Validation Accuracy: ', spam_val1_acc_50_svm)
spamY_pred1_50 = grid.predict(spamX_test1_50)
spam_test1_acc_50_svm = (np.sum(spamY_pred1_50 == spamY_test1_50) / len(spamY_test1_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_50_svm)

#spam 50/50 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train2_50, spamY_train2_50)
spam_train2_acc_50_svm = grid.cv_results_['mean_train_score'][0]
spam_val2_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_50_svm, ', Validation Accuracy: ', spam_val2_acc_50_svm)
spamY_pred2_50 = grid.predict(spamX_test2_50)
spam_test2_acc_50_svm = (np.sum(spamY_pred2_50 == spamY_test2_50) / len(spamY_test2_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_50_svm)
        
#spam 50/50 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train3_50, spamY_train3_50)
spam_train3_acc_50_svm = grid.cv_results_['mean_train_score'][0]
spam_val3_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_50_svm, ', Validation Accuracy: ', spam_val3_acc_50_svm)
spamY_pred3_50 = grid.predict(spamX_test3_50)
spam_test3_acc_50_svm = (np.sum(spamY_pred3_50 == spamY_test3_50) / len(spamY_test3_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_50_svm)

print()
print('Partition for 80/20')
# spam 80/20 1st trial
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train1_80, spamY_train1_80)
spam_train1_acc_80_svm = grid.cv_results_['mean_train_score'][0]
spam_val1_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_80_svm, ', Validation Accuracy: ', spam_val1_acc_80_svm)
spamY_pred1_80 = grid.predict(spamX_test1_80)
spam_test1_acc_80_svm = (np.sum(spamY_pred1_80 == spamY_test1_80) / len(spamY_test1_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_80_svm)

#spam 80/20 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train2_80, spamY_train2_80)
spam_train2_acc_80_svm = grid.cv_results_['mean_train_score'][0]
spam_val2_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_80_svm, ', Validation Accuracy: ', spam_val2_acc_80_svm)
spamY_pred2_80 = grid.predict(spamX_test2_80)
spam_test2_acc_80_svm = (np.sum(spamY_pred2_80 == spamY_test2_80) / len(spamY_test2_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_80_svm)

#spam 80/20 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(spamX_train3_80, spamY_train3_80)
spam_train3_acc_80_svm = grid.cv_results_['mean_train_score'][0]
spam_val3_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_80_svm, ', Validation Accuracy: ', spam_val3_acc_80_svm)
spamY_pred3_80 = grid.predict(spamX_test3_80)
spam_test3_acc_80_svm = (np.sum(spamY_pred3_80 == spamY_test3_80) / len(spamY_test3_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_80_svm)
# Out:
# Spambase Data
# Partition for 20/80
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9907593880685049 , Validation Accuracy:  0.8391304347826087
# Testing Accuracy:  0.8492257538712307
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9891307235733908 , Validation Accuracy:  0.8336956521739131
# Testing Accuracy:  0.845694104862809
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9869565140380429 , Validation Accuracy:  0.8347826086956521
# Testing Accuracy:  0.8429774517794077
#
# Partition for 50/50
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9806509373266022 , Validation Accuracy:  0.8739130434782608
# Testing Accuracy:  0.8913515862668405
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9789117116749103 , Validation Accuracy:  0.8573913043478261
# Testing Accuracy:  0.9035202086049544
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9810863877499587 , Validation Accuracy:  0.8808695652173913
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
spam_train_avg_20_svm = (spam_train1_acc_20_svm + spam_train2_acc_20_svm + spam_train3_acc_20_svm)/3
spam_train_avg_50_svm = (spam_train1_acc_50_svm + spam_train2_acc_50_svm + spam_train3_acc_50_svm)/3
spam_train_avg_80_svm = (spam_train1_acc_80_svm + spam_train2_acc_80_svm + spam_train3_acc_80_svm)/3

# Average validation accuracy
spam_val_avg_20_svm = (spam_val1_acc_20_svm + spam_val2_acc_20_svm + spam_val3_acc_20_svm)/3
spam_val_avg_50_svm = (spam_val1_acc_50_svm + spam_val2_acc_50_svm + spam_val3_acc_50_svm)/3
spam_val_avg_80_svm = (spam_val1_acc_80_svm + spam_val2_acc_80_svm + spam_val3_acc_80_svm)/3

# Average testing accuracy
spam_test_avg_20_svm = (spam_test1_acc_20_svm + spam_test2_acc_20_svm + spam_test3_acc_20_svm)/3
spam_test_avg_50_svm = (spam_test1_acc_50_svm + spam_test2_acc_50_svm + spam_test3_acc_50_svm)/3
spam_test_avg_80_svm = (spam_test1_acc_80_svm + spam_test2_acc_80_svm + spam_test3_acc_80_svm)/3

print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_train_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_train_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_train_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_val_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_val_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_val_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_test_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_test_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_test_avg_80_svm)
# Out:
# Average SVM Training Accuracy for Spambase Data 20/80:  0.9889488752266463
# Average SVM Training Accuracy for Spambase Data 50/50:  0.9802163455838238
# Average SVM Training Accuracy for Spambase Data 80/20:  0.9736408039991971
#
# Average SVM Validation Accuracy for Spambase Data 20/80:  0.8358695652173913
# Average SVM Validation Accuracy for Spambase Data 50/50:  0.8707246376811594
# Average SVM Validation Accuracy for Spambase Data 80/20:  0.8909420289855072
#
# Average SVM Testing Accuracy for Spambase Data 20/80:  0.8459657701711492
# Average SVM Testing Accuracy for Spambase Data 50/50:  0.8891786179921773
# Average SVM Testing Accuracy for Spambase Data 80/20:  0.9163952225841476

# %%
## Online Shoppers Data

grid = GridSearchCV(classifier, [{'C':[100],'gamma':[10e-6]}], n_jobs = -1, cv = 3, return_train_score= True, iid = True)

print('\033[1m' + 'Online Shoppers Data' + '\033[0m')
print('Partition for 20/80')
print('Best C: 100, Best gamma: 10e-6')
# shoppers 20/80 1st trial
grid.fit(shoppersX_train1_20, shoppersY_train1_20)
shoppers_train1_acc_20_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val1_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_20_svm, ', Validation Accuracy: ', shoppers_val1_acc_20_svm)
shoppersY_pred1_20 = grid.predict(shoppersX_test1_20)
shoppers_test1_acc_20_svm = (np.sum(shoppersY_pred1_20 == shoppersY_test1_20) / len(shoppersY_test1_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_20_svm)

#shoppers 20/80 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train2_20, shoppersY_train2_20)
shoppers_train2_acc_20_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val2_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_20_svm, ', Validation Accuracy: ', shoppers_val2_acc_20_svm)
shoppersY_pred2_20 = grid.predict(shoppersX_test2_20)
shoppers_test2_acc_20_svm = (np.sum(shoppersY_pred2_20 == shoppersY_test2_20) / len(shoppersY_test2_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_20_svm)

#shoppers 20/80 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train3_20, shoppersY_train3_20)
shoppers_train3_acc_20_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val3_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_20_svm, ', Validation Accuracy: ', shoppers_val3_acc_20_svm)
shoppersY_pred3_20 = grid.predict(shoppersX_test3_20)
shoppers_test3_acc_20_svm = (np.sum(shoppersY_pred3_20 == shoppersY_test3_20) / len(shoppersY_test3_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_20_svm)

print()
print('Partition for 50/50')
# shoppers 50/50 1st trial
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train1_50, shoppersY_train1_50)
shoppers_train1_acc_50_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val1_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_50_svm, ', Validation Accuracy: ', shoppers_val1_acc_50_svm)
shoppersY_pred1_50 = grid.predict(shoppersX_test1_50)
shoppers_test1_acc_50_svm = (np.sum(shoppersY_pred1_50 == shoppersY_test1_50) / len(shoppersY_test1_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_50_svm)

#shoppers 50/50 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train2_50, shoppersY_train2_50)
shoppers_train2_acc_50_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val2_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_50_svm, ', Validation Accuracy: ', shoppers_val2_acc_50_svm)
shoppersY_pred2_50 = grid.predict(shoppersX_test2_50)
shoppers_test2_acc_50_svm = (np.sum(shoppersY_pred2_50 == shoppersY_test2_50) / len(shoppersY_test2_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_50_svm)

#shoppers 50/50 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train3_50, shoppersY_train3_50)
shoppers_train3_acc_50_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val3_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_50_svm, ', Validation Accuracy: ', shoppers_val3_acc_50_svm)
shoppersY_pred3_50 = grid.predict(shoppersX_test3_50)
shoppers_test3_acc_50_svm = (np.sum(shoppersY_pred3_50 == shoppersY_test3_50) / len(shoppersY_test3_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_50_svm)

print()
print('Partition for 80/20')
# shoppers 80/20 1st trial
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train1_80, shoppersY_train1_80)
shoppers_train1_acc_80_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val1_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_80_svm, ', Validation Accuracy: ', shoppers_val1_acc_80_svm)
shoppersY_pred1_80 = grid.predict(shoppersX_test1_80)
shoppers_test1_acc_80_svm = (np.sum(shoppersY_pred1_80 == shoppersY_test1_80) / len(shoppersY_test1_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_80_svm)

#shoppers 80/20 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train2_80, shoppersY_train2_80)
shoppers_train2_acc_80_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val2_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_80_svm, ', Validation Accuracy: ', shoppers_val2_acc_80_svm)
shoppersY_pred2_80 = grid.predict(shoppersX_test2_80)
shoppers_test2_acc_80_svm = (np.sum(shoppersY_pred2_80 == shoppersY_test2_80) / len(shoppersY_test2_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_80_svm)

#shoppers 80/20 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-6')
grid.fit(shoppersX_train3_80, shoppersY_train3_80)
shoppers_train3_acc_80_svm = grid.cv_results_['mean_train_score'][0]
shoppers_val3_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_80_svm, ', Validation Accuracy: ', shoppers_val3_acc_80_svm)
shoppersY_pred3_80 = grid.predict(shoppersX_test3_80)
shoppers_test3_acc_80_svm = (np.sum(shoppersY_pred3_80 == shoppersY_test3_80) / len(shoppersY_test3_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_80_svm)
# Out:
# Online Shoppers Data
# Partition for 20/80
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.9446442284783553 , Validation Accuracy:  0.8730738037307381
# Testing Accuracy:  0.8734793187347932
# ---
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.940186769461941 , Validation Accuracy:  0.864963503649635
# Testing Accuracy:  0.8722627737226277
# ---
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.9420113544201135 , Validation Accuracy:  0.864963503649635
# Testing Accuracy:  0.8686131386861314
#
# Partition for 50/50
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.9301703163017031 , Validation Accuracy:  0.8768856447688564
# Testing Accuracy:  0.8780210867802108
# ---
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.9270882612056873 , Validation Accuracy:  0.8752635847526359
# Testing Accuracy:  0.8794809407948094
# ---
# Best C: 100, Best gamma: 10e-6
# Training Accuracy:  0.9300081103000811 , Validation Accuracy:  0.8814274128142742
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
shoppers_train_avg_20_svm = (shoppers_train1_acc_20_svm + shoppers_train2_acc_20_svm + shoppers_train3_acc_20_svm)/3
shoppers_train_avg_50_svm = (shoppers_train1_acc_50_svm + shoppers_train2_acc_50_svm + shoppers_train3_acc_50_svm)/3
shoppers_train_avg_80_svm = (shoppers_train1_acc_80_svm + shoppers_train2_acc_80_svm + shoppers_train3_acc_80_svm)/3

# Average validation accuracy
shoppers_val_avg_20_svm = (shoppers_val1_acc_20_svm + shoppers_val2_acc_20_svm + shoppers_val3_acc_20_svm)/3
shoppers_val_avg_50_svm = (shoppers_val1_acc_50_svm + shoppers_val2_acc_50_svm + shoppers_val3_acc_50_svm)/3
shoppers_val_avg_80_svm = (shoppers_val1_acc_80_svm + shoppers_val2_acc_80_svm + shoppers_val3_acc_80_svm)/3

# Average testing accuracy
shoppers_test_avg_20_svm = (shoppers_test1_acc_20_svm + shoppers_test2_acc_20_svm + shoppers_test3_acc_20_svm)/3
shoppers_test_avg_50_svm = (shoppers_test1_acc_50_svm + shoppers_test2_acc_50_svm + shoppers_test3_acc_50_svm)/3
shoppers_test_avg_80_svm = (shoppers_test1_acc_80_svm + shoppers_test2_acc_80_svm + shoppers_test3_acc_80_svm)/3

print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_train_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_train_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_train_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_val_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_val_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_val_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_test_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_test_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_test_avg_80_svm)
# Out:
# Average SVM Training Accuracy for Online Shoppers Data 20/80:  0.9422807841201366
# Average SVM Training Accuracy for Online Shoppers Data 50/50:  0.9290888959358239
# Average SVM Training Accuracy for Online Shoppers Data 80/20:  0.9241010459579734
#
# Average SVM Validation Accuracy for Online Shoppers Data 20/80:  0.8676669370100027
# Average SVM Validation Accuracy for Online Shoppers Data 50/50:  0.8778588807785889
# Average SVM Validation Accuracy for Online Shoppers Data 80/20:  0.8813192754798594
#
# Average SVM Testing Accuracy for Online Shoppers Data 20/80:  0.8714517437145175
# Average SVM Testing Accuracy for Online Shoppers Data 50/50:  0.8766693701000271
# Average SVM Testing Accuracy for Online Shoppers Data 80/20:  0.8779399837793997

# %%
## Electric Grid Data

grid = GridSearchCV(classifier, [{'C':[100],'gamma':[10e-4]}], n_jobs = -1, cv = 3, return_train_score= True, iid = True)

print('\033[1m' + 'Electric Grid Data' + '\033[0m')
print('Partition for 20/80')
print('Best C: 100, Best gamma: 10e-4')
# elecgrid 20/80 1st trial
grid.fit(elecgridX_train1_20, elecgridY_train1_20)
elecgrid_train1_acc_20_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_20_svm, ', Validation Accuracy: ', elecgrid_val1_acc_20_svm)
elecgridY_pred1_20 = grid.predict(elecgridX_test1_20)
elecgrid_test1_acc_20_svm = (np.sum(elecgridY_pred1_20 == elecgridY_test1_20) / len(elecgridY_test1_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_20_svm)

#elecgrid 20/80 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train2_20, elecgridY_train2_20)
elecgrid_train2_acc_20_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_20_svm, ', Validation Accuracy: ', elecgrid_val2_acc_20_svm)
elecgridY_pred2_20 = grid.predict(elecgridX_test2_20)
elecgrid_test2_acc_20_svm = (np.sum(elecgridY_pred2_20 == elecgridY_test2_20) / len(elecgridY_test2_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_20_svm)

#elecgrid 20/80 3rd trial
print('---')
print('Best C: 10, Best gamma: 10e-4')
grid.fit(elecgridX_train3_20, elecgridY_train3_20)
elecgrid_train3_acc_20_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_20_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_20_svm, ', Validation Accuracy: ', elecgrid_val3_acc_20_svm)
elecgridY_pred3_20 = grid.predict(elecgridX_test3_20)
elecgrid_test3_acc_20_svm = (np.sum(elecgridY_pred3_20 == elecgridY_test3_20) / len(elecgridY_test3_20))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_20_svm)

print()
print('Partition for 50/50')
# elecgrid 50/50 1st trial
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train1_50, elecgridY_train1_50)
elecgrid_train1_acc_50_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_50_svm, ', Validation Accuracy: ', elecgrid_val1_acc_50_svm)
elecgridY_pred1_50 = grid.predict(elecgridX_test1_50)
elecgrid_test1_acc_50_svm = (np.sum(elecgridY_pred1_50 == elecgridY_test1_50) / len(elecgridY_test1_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_50_svm)

#elecgrid 50/50 2nd trial
print('---')
print('Best C: 10, Best gamma: 10e-4')
grid.fit(elecgridX_train2_50, elecgridY_train2_50)
elecgrid_train2_acc_50_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_50_svm, ', Validation Accuracy: ', elecgrid_val2_acc_50_svm)
elecgridY_pred2_50 = grid.predict(elecgridX_test2_50)
elecgrid_test2_acc_50_svm = (np.sum(elecgridY_pred2_50 == elecgridY_test2_50) / len(elecgridY_test2_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_50_svm)

#elecgrid 50/50 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train3_50, elecgridY_train3_50)
elecgrid_train3_acc_50_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_50_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_50_svm, ', Validation Accuracy: ', elecgrid_val3_acc_50_svm)
elecgridY_pred3_50 = grid.predict(elecgridX_test3_50)
elecgrid_test3_acc_50_svm = (np.sum(elecgridY_pred3_50 == elecgridY_test3_50) / len(elecgridY_test3_50))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_50_svm)

print()
print('Partition for 80/20')
# elecgrid 80/20 1st trial
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train1_80, elecgridY_train1_80)
elecgrid_train1_acc_80_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_80_svm, ', Validation Accuracy: ', elecgrid_val1_acc_80_svm)
elecgridY_pred1_80 = grid.predict(elecgridX_test1_80)
elecgrid_test1_acc_80_svm = (np.sum(elecgridY_pred1_80 == elecgridY_test1_80) / len(elecgridY_test1_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_80_svm)

#elecgrid 80/20 2nd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train2_80, elecgridY_train2_80)
elecgrid_train2_acc_80_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_80_svm, ', Validation Accuracy: ', elecgrid_val2_acc_80_svm)
elecgridY_pred2_80 = grid.predict(elecgridX_test2_80)
elecgrid_test2_acc_80_svm = (np.sum(elecgridY_pred2_80 == elecgridY_test2_80) / len(elecgridY_test2_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_80_svm)

#elecgrid 80/20 3rd trial
print('---')
print('Best C: 100, Best gamma: 10e-4')
grid.fit(elecgridX_train3_80, elecgridY_train3_80)
elecgrid_train3_acc_80_svm = grid.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_80_svm = grid.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_80_svm, ', Validation Accuracy: ', elecgrid_val3_acc_80_svm)
elecgridY_pred3_80 = grid.predict(elecgridX_test3_80)
elecgrid_test3_acc_80_svm = (np.sum(elecgridY_pred3_80 == elecgridY_test3_80) / len(elecgridY_test3_80))
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_80_svm)
# Out:
# Electric Grid Data
# Partition for 20/80
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.8822484856596459 , Validation Accuracy:  0.8675
# Testing Accuracy:  0.884625
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.8797465483312358 , Validation Accuracy:  0.8715
# Testing Accuracy:  0.881
# ---
# Best C: 10, Best gamma: 10e-4
# Training Accuracy:  0.881498815156986 , Validation Accuracy:  0.87
# Testing Accuracy:  0.88275
#
# Partition for 50/50
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.8988998779901985 , Validation Accuracy:  0.8914
# Testing Accuracy:  0.9042
# ---
# Best C: 10, Best gamma: 10e-4
# Training Accuracy:  0.8990003919984311 , Validation Accuracy:  0.8922
# Testing Accuracy:  0.9014
# ---
# Best C: 100, Best gamma: 10e-4
# Training Accuracy:  0.9020007523105223 , Validation Accuracy:  0.8958
# Testing Accuracy:  0.898
#
# Partition for 80/20
# Best C: 100, Best gamma: 10e-4
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
elecgrid_train_avg_20_svm = (elecgrid_train1_acc_20_svm + elecgrid_train2_acc_20_svm + elecgrid_train3_acc_20_svm)/3
elecgrid_train_avg_50_svm = (elecgrid_train1_acc_50_svm + elecgrid_train2_acc_50_svm + elecgrid_train3_acc_50_svm)/3
elecgrid_train_avg_80_svm = (elecgrid_train1_acc_80_svm + elecgrid_train2_acc_80_svm + elecgrid_train3_acc_80_svm)/3

# Average validation accuracy
elecgrid_val_avg_20_svm = (elecgrid_val1_acc_20_svm + elecgrid_val2_acc_20_svm + elecgrid_val3_acc_20_svm)/3
elecgrid_val_avg_50_svm = (elecgrid_val1_acc_50_svm + elecgrid_val2_acc_50_svm + elecgrid_val3_acc_50_svm)/3
elecgrid_val_avg_80_svm = (elecgrid_val1_acc_80_svm + elecgrid_val2_acc_80_svm + elecgrid_val3_acc_80_svm)/3

# Average testing accuracy
elecgrid_test_avg_20_svm = (elecgrid_test1_acc_20_svm + elecgrid_test2_acc_20_svm + elecgrid_test3_acc_20_svm)/3
elecgrid_test_avg_50_svm = (elecgrid_test1_acc_50_svm + elecgrid_test2_acc_50_svm + elecgrid_test3_acc_50_svm)/3
elecgrid_test_avg_80_svm = (elecgrid_test1_acc_80_svm + elecgrid_test2_acc_80_svm + elecgrid_test3_acc_80_svm)/3

print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_train_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_train_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_train_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_val_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_val_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_val_avg_80_svm)
print()

print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_test_avg_20_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_test_avg_50_svm)
print('Average SVM ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for elecgrid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_test_avg_80_svm)
# Out:
# Average SVM Training Accuracy for elecgrid Data 20/80:  0.8811646163826227
# Average SVM Training Accuracy for elecgrid Data 50/50:  0.8999670074330507
# Average SVM Training Accuracy for elecgrid Data 80/20:  0.9084791053226596
#
# Average SVM Validation Accuracy for elecgrid Data 20/80:  0.8696666666666667
# Average SVM Validation Accuracy for elecgrid Data 50/50:  0.8931333333333332
# Average SVM Validation Accuracy for elecgrid Data 80/20:  0.9033749999999999
#
# Average SVM Testing Accuracy for elecgrid Data 20/80:  0.8827916666666668
# Average SVM Testing Accuracy for elecgrid Data 50/50:  0.9012000000000001
# Average SVM Testing Accuracy for elecgrid Data 80/20:  0.9151666666666666

# %% [markdown]
# ## Decision Tree

# %%
classifier = tree.DecisionTreeClassifier(criterion='entropy')

# %%
## Spambase Data

print('\033[1m' + 'Spambase Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 5, Best max features: 12, Best samples split: 6')
# spam 20/80 1st trial
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [6], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train1_20, spamY_train1_20)
spam_train1_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_20_dt, ', Validation Accuracy: ', spam_val1_acc_20_dt)
spam_test1_acc_20_dt = sum(grid_search.best_estimator_.predict(spamX_test1_20) == spamY_test1_20) / len(spamX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_20_dt)

#spam 20/80 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 7')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [7], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train2_20, spamY_train2_20)
spam_train2_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_20_dt, ', Validation Accuracy: ', spam_val2_acc_20_dt)
spam_test2_acc_20_dt = sum(grid_search.best_estimator_.predict(spamX_test2_20) == spamY_test2_20) / len(spamX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_20_dt)

#spam 20/80 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 4')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [4], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train3_20, spamY_train3_20)
spam_train3_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_20_dt, ', Validation Accuracy: ', spam_val3_acc_20_dt)
spam_test3_acc_20_dt = sum(grid_search.best_estimator_.predict(spamX_test3_20) == spamY_test3_20) / len(spamX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_20_dt)

print()
print('Partition for 50/50')
# spam 50/50 1st trial
print('Best depth: 5, Best max features: 12, Best samples split: 4')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [4], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train1_50, spamY_train1_50)
spam_train1_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_50_dt, ', Validation Accuracy: ', spam_val1_acc_50_dt)
spam_test1_acc_50_dt = sum(grid_search.best_estimator_.predict(spamX_test1_50) == spamY_test1_50) / len(spamX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_50_dt)

#spam 50/50 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 5')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [5], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train2_50, spamY_train2_50)
spam_train2_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_50_dt, ', Validation Accuracy: ', spam_val2_acc_50_dt)
spam_test2_acc_50_dt = sum(grid_search.best_estimator_.predict(spamX_test2_50) == spamY_test2_50) / len(spamX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_50_dt)

#spam 50/50 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 6')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [6], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train3_50, spamY_train3_50)
spam_train3_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_50_dt, ', Validation Accuracy: ', spam_val3_acc_50_dt)
spam_test3_acc_50_dt = sum(grid_search.best_estimator_.predict(spamX_test3_50) == spamY_test3_50) / len(spamX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_50_dt)

print()
print('Partition for 80/20')
# spam 80/20 1st trial
print('Best depth: 5, Best max features: 8, Best samples split: 7')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [7], "max_features": [8]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train1_80, spamY_train1_80)
spam_train1_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_80_dt, ', Validation Accuracy: ', spam_val1_acc_80_dt)
spam_test1_acc_80_dt = sum(grid_search.best_estimator_.predict(spamX_test1_80) == spamY_test1_80) / len(spamX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_80_dt)

#spam 80/20 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 3')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [3], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train2_80, spamY_train2_80)
spam_train2_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_80_dt, ', Validation Accuracy: ', spam_val2_acc_80_dt)
spam_test2_acc_80_dt = sum(grid_search.best_estimator_.predict(spamX_test2_80) == spamY_test2_80) / len(spamX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_80_dt)

#spam 80/20 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 6')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [6], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(spamX_train3_80, spamY_train3_80)
spam_train3_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_80_dt, ', Validation Accuracy: ', spam_val3_acc_80_dt)
spam_test3_acc_80_dt = sum(grid_search.best_estimator_.predict(spamX_test3_80) == spamY_test3_80) / len(spamX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_80_dt)
# Out:
# Spambase Data
# Partition for 20/80
# Best depth: 5, Best max features: 12, Best samples split: 6
# Training Accuracy:  0.9015700483091788 , Validation Accuracy:  0.8695652173913043
# Testing Accuracy:  0.8660690029883183
# ---
# Best depth: 5, Best max features: 12, Best samples split: 7
# Training Accuracy:  0.903502301306647 , Validation Accuracy:  0.8717391304347826
# Testing Accuracy:  0.8486824232545503
# ---
# Best depth: 5, Best max features: 12, Best samples split: 4
# Training Accuracy:  0.9051854238010527 , Validation Accuracy:  0.875
# Testing Accuracy:  0.8820972561803858
#
# Partition for 50/50
# Best depth: 5, Best max features: 12, Best samples split: 4
# Training Accuracy:  0.8989397697887439 , Validation Accuracy:  0.878695652173913
# Testing Accuracy:  0.8491960017383746
# ---
# Best depth: 5, Best max features: 12, Best samples split: 5
# Training Accuracy:  0.8935744304991781 , Validation Accuracy:  0.8634782608695653
# Testing Accuracy:  0.8552803129074316
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
spam_train_avg_20_dt = (spam_train1_acc_20_dt + spam_train2_acc_20_dt + spam_train3_acc_20_dt)/3
spam_train_avg_50_dt = (spam_train1_acc_50_dt + spam_train2_acc_50_dt + spam_train3_acc_50_dt)/3
spam_train_avg_80_dt = (spam_train1_acc_80_dt + spam_train2_acc_80_dt + spam_train3_acc_80_dt)/3

# Average validation accuracy
spam_val_avg_20_dt = (spam_val1_acc_20_dt + spam_val2_acc_20_dt + spam_val3_acc_20_dt)/3
spam_val_avg_50_dt = (spam_val1_acc_50_dt + spam_val2_acc_50_dt + spam_val3_acc_50_dt)/3
spam_val_avg_80_dt = (spam_val1_acc_80_dt + spam_val2_acc_80_dt + spam_val3_acc_80_dt)/3

# Average testing accuracy
spam_test_avg_20_dt = (spam_test1_acc_20_dt + spam_test2_acc_20_dt + spam_test3_acc_20_dt)/3
spam_test_avg_50_dt = (spam_test1_acc_50_dt + spam_test2_acc_50_dt + spam_test3_acc_50_dt)/3
spam_test_avg_80_dt = (spam_test1_acc_80_dt + spam_test2_acc_80_dt + spam_test3_acc_80_dt)/3

print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_train_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_train_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_train_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_val_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_val_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_val_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_test_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_test_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_test_avg_80_dt)
# Out:
# Average dt Training Accuracy for Spambase Data 20/80:  0.9034192578056262
# Average dt Training Accuracy for Spambase Data 50/50:  0.895555954902056
# Average dt Training Accuracy for Spambase Data 80/20:  0.8876513599403587
#
# Average dt Validation Accuracy for Spambase Data 20/80:  0.8721014492753624
# Average dt Validation Accuracy for Spambase Data 50/50:  0.8723188405797102
# Average dt Validation Accuracy for Spambase Data 80/20:  0.8740036231884057
#
# Average dt Testing Accuracy for Spambase Data 20/80:  0.8656162274744181
# Average dt Testing Accuracy for Spambase Data 50/50:  0.8609300304215558
# Average dt Testing Accuracy for Spambase Data 80/20:  0.8859934853420195

# %%
# Online Shoppers Data

print('\033[1m' + 'Online Shoppers Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 5, Best max features: 12, Best samples split: 2')
# shoppers 20/80 1st trial
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [2], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train1_20, shoppersY_train1_20)
shoppers_train1_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_20_dt, ', Validation Accuracy: ', shoppers_val1_acc_20_dt)
shoppers_test1_acc_20_dt = sum(grid_search.best_estimator_.predict(shoppersX_test1_20) == shoppersY_test1_20) / len(shoppersX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_20_dt)

#shoppers 20/80 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 2')
grid_search.fit(shoppersX_train2_20, shoppersY_train2_20)
shoppers_train2_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_20_dt, ', Validation Accuracy: ', shoppers_val2_acc_20_dt)
shoppers_test2_acc_20_dt = sum(grid_search.best_estimator_.predict(shoppersX_test2_20) == shoppersY_test2_20) / len(shoppersX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_20_dt)

#shoppers 20/80 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 6')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [6], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train3_20, shoppersY_train3_20)
shoppers_train3_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_20_dt, ', Validation Accuracy: ', shoppers_val3_acc_20_dt)
shoppers_test3_acc_20_dt = sum(grid_search.best_estimator_.predict(shoppersX_test3_20) == shoppersY_test3_20) / len(shoppersX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_20_dt)

print()
print('Partition for 50/50')
# shoppers 50/50 1st trial
print('Best depth: 5, Best max features: 12, Best samples split: 6')
grid_search.fit(shoppersX_train1_50, shoppersY_train1_50)
shoppers_train1_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_50_dt, ', Validation Accuracy: ', shoppers_val1_acc_50_dt)
shoppers_test1_acc_50_dt = sum(grid_search.best_estimator_.predict(shoppersX_test1_50) == shoppersY_test1_50) / len(shoppersX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_50_dt)

#shoppers 50/50 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 3')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [3], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train2_50, shoppersY_train2_50)
shoppers_train2_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_50_dt, ', Validation Accuracy: ', shoppers_val2_acc_50_dt)
shoppers_test2_acc_50_dt = sum(grid_search.best_estimator_.predict(shoppersX_test2_50) == shoppersY_test2_50) / len(shoppersX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_50_dt)

#shoppers 50/50 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 6')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [6], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train3_50, shoppersY_train3_50)
shoppers_train3_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_50_dt, ', Validation Accuracy: ', shoppers_val3_acc_50_dt)
shoppers_test3_acc_50_dt = sum(grid_search.best_estimator_.predict(shoppersX_test3_50) == shoppersY_test3_50) / len(shoppersX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_50_dt)

print()
print('Partition for 80/20')
# shoppers 80/20 1st trial
print('Best depth: 5, Best max features: 12, Best samples split: 5')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [5], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train1_80, shoppersY_train1_80)
shoppers_train1_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_80_dt, ', Validation Accuracy: ', shoppers_val1_acc_80_dt)
shoppers_test1_acc_80_dt = sum(grid_search.best_estimator_.predict(shoppersX_test1_80) == shoppersY_test1_80) / len(shoppersX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_80_dt)

#shoppers 80/20 2nd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 5')
grid_search.fit(shoppersX_train2_80, shoppersY_train2_80)
shoppers_train2_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_80_dt, ', Validation Accuracy: ', shoppers_val2_acc_80_dt)
shoppers_test2_acc_80_dt = sum(grid_search.best_estimator_.predict(shoppersX_test2_80) == shoppersY_test2_80) / len(shoppersX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_80_dt)

#shoppers 80/20 3rd trial
print('---')
print('Best depth: 5, Best max features: 12, Best samples split: 7')
grid_search = GridSearchCV(classifier, {"max_depth": [5], "min_samples_split": [7], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(shoppersX_train3_80, shoppersY_train3_80)
shoppers_train3_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_80_dt, ', Validation Accuracy: ', shoppers_val3_acc_80_dt)
shoppers_test3_acc_80_dt = sum(grid_search.best_estimator_.predict(shoppersX_test3_80) == shoppersY_test3_80) / len(shoppersX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_80_dt)
# Out:
# Online Shoppers Data
# Partition for 20/80
# Best depth: 5, Best max features: 12, Best samples split: 2
# Training Accuracy:  0.9036217597218499 , Validation Accuracy:  0.8832116788321168
# Testing Accuracy:  0.8907137064071371
# ---
# Best depth: 5, Best max features: 12, Best samples split: 2
# Training Accuracy:  0.9076331485738034 , Validation Accuracy:  0.8937550689375506
# Testing Accuracy:  0.8956812652068127
# ---
# Best depth: 5, Best max features: 12, Best samples split: 6
# Training Accuracy:  0.9065055682090384 , Validation Accuracy:  0.8860502838605029
# Testing Accuracy:  0.8972019464720195
#
# Partition for 50/50
# Best depth: 5, Best max features: 12, Best samples split: 6
# Training Accuracy:  0.8969087053275633 , Validation Accuracy:  0.8869424168694242
# Testing Accuracy:  0.8994322789943228
# ---
# Best depth: 5, Best max features: 12, Best samples split: 3
# Training Accuracy:  0.9002433839150916 , Validation Accuracy:  0.8947283049472831
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
shoppers_train_avg_20_dt = (shoppers_train1_acc_20_dt + shoppers_train2_acc_20_dt + shoppers_train3_acc_20_dt)/3
shoppers_train_avg_50_dt = (shoppers_train1_acc_50_dt + shoppers_train2_acc_50_dt + shoppers_train3_acc_50_dt)/3
shoppers_train_avg_80_dt = (shoppers_train1_acc_80_dt + shoppers_train2_acc_80_dt + shoppers_train3_acc_80_dt)/3

# Average validation accuracy
shoppers_val_avg_20_dt = (shoppers_val1_acc_20_dt + shoppers_val2_acc_20_dt + shoppers_val3_acc_20_dt)/3
shoppers_val_avg_50_dt = (shoppers_val1_acc_50_dt + shoppers_val2_acc_50_dt + shoppers_val3_acc_50_dt)/3
shoppers_val_avg_80_dt = (shoppers_val1_acc_80_dt + shoppers_val2_acc_80_dt + shoppers_val3_acc_80_dt)/3

# Average testing accuracy
shoppers_test_avg_20_dt = (shoppers_test1_acc_20_dt + shoppers_test2_acc_20_dt + shoppers_test3_acc_20_dt)/3
shoppers_test_avg_50_dt = (shoppers_test1_acc_50_dt + shoppers_test2_acc_50_dt + shoppers_test3_acc_50_dt)/3
shoppers_test_avg_80_dt = (shoppers_test1_acc_80_dt + shoppers_test2_acc_80_dt + shoppers_test3_acc_80_dt)/3

print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_train_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_train_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_train_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_val_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_val_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_val_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_test_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_test_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_test_avg_80_dt)
# Out:
# Average dt Training Accuracy for Online Shoppers Data 20/80:  0.9059201588348973
# Average dt Training Accuracy for Online Shoppers Data 50/50:  0.899125843034189
# Average dt Training Accuracy for Online Shoppers Data 80/20:  0.8976937597594302
#
# Average dt Validation Accuracy for Online Shoppers Data 20/80:  0.8876723438767234
# Average dt Validation Accuracy for Online Shoppers Data 50/50:  0.8901324682346581
# Average dt Validation Accuracy for Online Shoppers Data 80/20:  0.892065423087321
#
# Average dt Testing Accuracy for Online Shoppers Data 20/80:  0.8945323060286564
# Average dt Testing Accuracy for Online Shoppers Data 50/50:  0.890727223573939
# Average dt Testing Accuracy for Online Shoppers Data 80/20:  0.8930792105974588

# %%
# Electric Grid Data

grid_search = GridSearchCV(classifier, {"max_depth": [1], "min_samples_split": [5], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.

print('\033[1m' + 'Electric Grid Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 1, Best max features: 12, Best samples split: 5')
# elecgrid 20/80 1st trial
grid_search.fit(elecgridX_train1_20, elecgridY_train1_20)
elecgrid_train1_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_20_dt, ', Validation Accuracy: ', elecgrid_val1_acc_20_dt)
elecgrid_test1_acc_20_dt = sum(grid_search.best_estimator_.predict(elecgridX_test1_20) == elecgridY_test1_20) / len(elecgridX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_20_dt)

#elecgrid 20/80 2nd trial
print('---')
print('Best depth: 1, Best max features: 12, Best samples split: 2')
grid_search = GridSearchCV(classifier, {"max_depth": [1], "min_samples_split": [2], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train2_20, elecgridY_train2_20)
elecgrid_train2_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_20_dt, ', Validation Accuracy: ', elecgrid_val2_acc_20_dt)
elecgrid_test2_acc_20_dt = sum(grid_search.best_estimator_.predict(elecgridX_test2_20) == elecgridY_test2_20) / len(elecgridX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_20_dt)

#elecgrid 20/80 3rd trial
print('---')
print('Best depth: 1, Best max features: 12, Best samples split: 4')
grid_search = GridSearchCV(classifier, {"max_depth": [1], "min_samples_split": [4], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train3_20, elecgridY_train3_20)
elecgrid_train3_acc_20_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_20_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_20_dt, ', Validation Accuracy: ', elecgrid_val3_acc_20_dt)
elecgrid_test3_acc_20_dt = sum(grid_search.best_estimator_.predict(elecgridX_test3_20) == elecgridY_test3_20) / len(elecgridX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_20_dt)

print()
print('Partition for 50/50')
# elecgrid 50/50 1st trial
print('Best depth: 1, Best max features: 12, Best samples split: 2')
grid_search = GridSearchCV(classifier, {"max_depth": [1], "min_samples_split": [2], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train1_50, elecgridY_train1_50)
elecgrid_train1_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_50_dt, ', Validation Accuracy: ', elecgrid_val1_acc_50_dt)
elecgrid_test1_acc_50_dt = sum(grid_search.best_estimator_.predict(elecgridX_test1_50) == elecgridY_test1_50) / len(elecgridX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_50_dt)

#elecgrid 50/50 2nd trial
print('---')
print('Best depth: 2, Best max features: 12, Best samples split: 5')
grid_search = GridSearchCV(classifier, {"max_depth": [2], "min_samples_split": [5], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train2_50, elecgridY_train2_50)
elecgrid_train2_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_50_dt, ', Validation Accuracy: ', elecgrid_val2_acc_50_dt)
elecgrid_test2_acc_50_dt = sum(grid_search.best_estimator_.predict(elecgridX_test2_50) == elecgridY_test2_50) / len(elecgridX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_50_dt)

#elecgrid 50/50 3rd trial
print('---')
print('Best depth: 2, Best max features: 12, Best samples split: 5')
grid_search.fit(elecgridX_train3_50, elecgridY_train3_50)
elecgrid_train3_acc_50_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_50_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_50_dt, ', Validation Accuracy: ', elecgrid_val3_acc_50_dt)
elecgrid_test3_acc_50_dt = sum(grid_search.best_estimator_.predict(elecgridX_test3_50) == elecgridY_test3_50) / len(elecgridX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_50_dt)

print()
print('Partition for 80/20')
# elecgrid 80/20 1st trial
print('Best depth: 3, Best max features: 8, Best samples split: 4')
grid_search = GridSearchCV(classifier, {"max_depth": [3], "min_samples_split": [4], "max_features": [8]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train1_80, elecgridY_train1_80)
elecgrid_train1_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_80_dt, ', Validation Accuracy: ', elecgrid_val1_acc_80_dt)
elecgrid_test1_acc_80_dt = sum(grid_search.best_estimator_.predict(elecgridX_test1_80) == elecgridY_test1_80) / len(elecgridX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_80_dt)

#elecgrid 80/20 2nd trial
print('---')
print('Best depth: 3, Best max features: 12, Best samples split: 2')
grid_search = GridSearchCV(classifier, {"max_depth": [3], "min_samples_split": [2], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train2_80, elecgridY_train2_80)
elecgrid_train2_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_80_dt, ', Validation Accuracy: ', elecgrid_val2_acc_80_dt)
elecgrid_test2_acc_80_dt = sum(grid_search.best_estimator_.predict(elecgridX_test2_80) == elecgridY_test2_80) / len(elecgridX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_80_dt)

#elecgrid 80/20 3rd trial
print('---')
print('Best depth: 4, Best max features: 8, Best samples split: 5')
grid_search = GridSearchCV(classifier, {"max_depth": [4], "min_samples_split": [5], "max_features": [8]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train3_80, elecgridY_train3_80)
elecgrid_train3_acc_80_dt = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_80_dt = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_80_dt, ', Validation Accuracy: ', elecgrid_val3_acc_80_dt)
elecgrid_test3_acc_80_dt = sum(grid_search.best_estimator_.predict(elecgridX_test3_80) == elecgridY_test3_80) / len(elecgridX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_80_dt)
# Out:
# Electric Grid Data
# Partition for 20/80
# Best depth: 1, Best max features: 12, Best samples split: 5
# Training Accuracy:  0.9693162868260146 , Validation Accuracy:  0.9655
# Testing Accuracy:  0.999875
# ---
# Best depth: 1, Best max features: 12, Best samples split: 2
# Training Accuracy:  1.0 , Validation Accuracy:  1.0
# Testing Accuracy:  0.999375
# ---
# Best depth: 1, Best max features: 12, Best samples split: 4
# Training Accuracy:  0.969905607995558 , Validation Accuracy:  0.9695
# Testing Accuracy:  0.67825
#
# Partition for 50/50
# Best depth: 1, Best max features: 12, Best samples split: 2
# Training Accuracy:  1.0 , Validation Accuracy:  0.9998
# Testing Accuracy:  0.9998
# ---
# Best depth: 2, Best max features: 12, Best samples split: 5
# Training Accuracy:  1.0 , Validation Accuracy:  0.9998
# Testing Accuracy:  0.9998
# ---
# Best depth: 2, Best max features: 12, Best samples split: 5
# Training Accuracy:  1.0 , Validation Accuracy:  0.9996
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
elecgrid_train_avg_20_dt = (elecgrid_train1_acc_20_dt + elecgrid_train2_acc_20_dt + elecgrid_train3_acc_20_dt)/3
elecgrid_train_avg_50_dt = (elecgrid_train1_acc_50_dt + elecgrid_train2_acc_50_dt + elecgrid_train3_acc_50_dt)/3
elecgrid_train_avg_80_dt = (elecgrid_train1_acc_80_dt + elecgrid_train2_acc_80_dt + elecgrid_train3_acc_80_dt)/3

# Average validation accuracy
elecgrid_val_avg_20_dt = (elecgrid_val1_acc_20_dt + elecgrid_val2_acc_20_dt + elecgrid_val3_acc_20_dt)/3
elecgrid_val_avg_50_dt = (elecgrid_val1_acc_50_dt + elecgrid_val2_acc_50_dt + elecgrid_val3_acc_50_dt)/3
elecgrid_val_avg_80_dt = (elecgrid_val1_acc_80_dt + elecgrid_val2_acc_80_dt + elecgrid_val3_acc_80_dt)/3

# Average testing accuracy
elecgrid_test_avg_20_dt = (elecgrid_test1_acc_20_dt + elecgrid_test2_acc_20_dt + elecgrid_test3_acc_20_dt)/3
elecgrid_test_avg_50_dt = (elecgrid_test1_acc_50_dt + elecgrid_test2_acc_50_dt + elecgrid_test3_acc_50_dt)/3
elecgrid_test_avg_80_dt = (elecgrid_test1_acc_80_dt + elecgrid_test2_acc_80_dt + elecgrid_test3_acc_80_dt)/3

print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_train_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_train_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_train_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_val_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_val_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_val_avg_80_dt)
print()

print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_test_avg_20_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_test_avg_50_dt)
print('Average dt ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_test_avg_80_dt)
# Out:
# Average dt Training Accuracy for Electric Grid Data 20/80:  0.9797406316071909
# Average dt Training Accuracy for Electric Grid Data 50/50:  1.0
# Average dt Training Accuracy for Electric Grid Data 80/20:  1.0
#
# Average dt Validation Accuracy for Electric Grid Data 20/80:  0.9783333333333334
# Average dt Validation Accuracy for Electric Grid Data 50/50:  0.9997333333333334
# Average dt Validation Accuracy for Electric Grid Data 80/20:  0.99975
#
# Average dt Testing Accuracy for Electric Grid Data 20/80:  0.8925000000000001
# Average dt Testing Accuracy for Electric Grid Data 50/50:  0.9998
# Average dt Testing Accuracy for Electric Grid Data 80/20:  1.0

# %% [markdown]
# ## Random Forest Classifier

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# %%
## Spambase Data
grid_search = GridSearchCV(clf, {'max_depth': [5], "max_features": [16]}, return_train_score = True, cv = 10, iid = True) # 10-fold.

print('\033[1m' + 'Spambase Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 5, Best number of features: 16')
# spam 20/80 1st trial
grid_search.fit(spamX_train1_20, spamY_train1_20)
spam_train1_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_20_rf, ', Validation Accuracy: ', spam_val1_acc_20_rf)
spam_test1_acc_20_rf = sum(grid_search.best_estimator_.predict(spamX_test1_20) == spamY_test1_20) / len(spamX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_20_rf)

#spam 20/80 2nd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train2_20, spamY_train2_20)
spam_train2_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_20_rf, ', Validation Accuracy: ', spam_val2_acc_20_rf)
spam_test2_acc_20_rf = sum(grid_search.best_estimator_.predict(spamX_test2_20) == spamY_test2_20) / len(spamX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_20_rf)

#spam 20/80 3rd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train3_20, spamY_train3_20)
spam_train3_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_20_rf, ', Validation Accuracy: ', spam_val3_acc_20_rf)
spam_test3_acc_20_rf = sum(grid_search.best_estimator_.predict(spamX_test3_20) == spamY_test3_20) / len(spamX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_20_rf)

print()
print('Partition for 50/50')
# spam 50/50 1st trial
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train1_50, spamY_train1_50)
spam_train1_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_50_rf, ', Validation Accuracy: ', spam_val1_acc_50_rf)
spam_test1_acc_50_rf = sum(grid_search.best_estimator_.predict(spamX_test1_50) == spamY_test1_50) / len(spamX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_50_rf)

#spam 50/50 2nd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train2_50, spamY_train2_50)
spam_train2_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_50_rf, ', Validation Accuracy: ', spam_val2_acc_50_rf)
spam_test2_acc_50_rf = sum(grid_search.best_estimator_.predict(spamX_test2_50) == spamY_test2_50) / len(spamX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_50_rf)

#spam 50/50 3rd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train3_50, spamY_train3_50)
spam_train3_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_50_rf, ', Validation Accuracy: ', spam_val3_acc_50_rf)
spam_test3_acc_50_rf = sum(grid_search.best_estimator_.predict(spamX_test3_50) == spamY_test3_50) / len(spamX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_50_rf)

print()
print('Partition for 80/20')
# spam 80/20 1st trial
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train1_80, spamY_train1_80)
spam_train1_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val1_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train1_acc_80_rf, ', Validation Accuracy: ', spam_val1_acc_80_rf)
spam_test1_acc_80_rf = sum(grid_search.best_estimator_.predict(spamX_test1_80) == spamY_test1_80) / len(spamX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test1_acc_80_rf)

#spam 80/20 2nd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train2_80, spamY_train2_80)
spam_train2_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val2_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train2_acc_80_rf, ', Validation Accuracy: ', spam_val2_acc_80_rf)
spam_test2_acc_80_rf = sum(grid_search.best_estimator_.predict(spamX_test2_80) == spamY_test2_80) / len(spamX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test2_acc_80_rf)

#spam 80/20 3rd trial
print('---')
print('Best depth: 5, Best number of features: 16')
grid_search.fit(spamX_train3_80, spamY_train3_80)
spam_train3_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
spam_val3_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', spam_train3_acc_80_rf, ', Validation Accuracy: ', spam_val3_acc_80_rf)
spam_test3_acc_80_rf = sum(grid_search.best_estimator_.predict(spamX_test3_80) == spamY_test3_80) / len(spamX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', spam_test3_acc_80_rf)
# Out:
# Spambase Data
# Partition for 20/80
# Best depth: 5, Best number of features: 16
# Training Accuracy:  0.9578502415458937 , Validation Accuracy:  0.9434782608695652
# Testing Accuracy:  0.9220320565063841
# ---
# Best depth: 5, Best number of features: 16
# Training Accuracy:  0.9602668215713246 , Validation Accuracy:  0.9293478260869565
# Testing Accuracy:  0.9214887258897039
# ---
# Best depth: 5, Best number of features: 16
# Training Accuracy:  0.9605069204790695 , Validation Accuracy:  0.941304347826087
# Testing Accuracy:  0.923933713664765
#
# Partition for 50/50
# Best depth: 5, Best number of features: 16
# Training Accuracy:  0.9459901880133043 , Validation Accuracy:  0.93
# Testing Accuracy:  0.9261190786614515
# ---
# Best depth: 5, Best number of features: 16
# Training Accuracy:  0.9386955091934123 , Validation Accuracy:  0.9278260869565217
# Testing Accuracy:  0.9282920469361148
# ---
# Best depth: 5, Best number of features: 16
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
spam_train_avg_20_rf = (spam_train1_acc_20_rf + spam_train2_acc_20_rf + spam_train3_acc_20_rf)/3
spam_train_avg_50_rf = (spam_train1_acc_50_rf + spam_train2_acc_50_rf + spam_train3_acc_50_rf)/3
spam_train_avg_80_rf = (spam_train1_acc_80_rf + spam_train2_acc_80_rf + spam_train3_acc_80_rf)/3

# Average validation accuracy
spam_val_avg_20_rf = (spam_val1_acc_20_rf + spam_val2_acc_20_rf + spam_val3_acc_20_rf)/3
spam_val_avg_50_rf = (spam_val1_acc_50_rf + spam_val2_acc_50_rf + spam_val3_acc_50_rf)/3
spam_val_avg_80_rf = (spam_val1_acc_80_rf + spam_val2_acc_80_rf + spam_val3_acc_80_rf)/3

# Average testing accuracy
spam_test_avg_20_rf = (spam_test1_acc_20_rf + spam_test2_acc_20_rf + spam_test3_acc_20_rf)/3
spam_test_avg_50_rf = (spam_test1_acc_50_rf + spam_test2_acc_50_rf + spam_test3_acc_50_rf)/3
spam_test_avg_80_rf = (spam_test1_acc_80_rf + spam_test2_acc_80_rf + spam_test3_acc_80_rf)/3

print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_train_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_train_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_train_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_val_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_val_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_val_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '20/80: ' + '\033[0m', spam_test_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '50/50: ' + '\033[0m', spam_test_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Spambase Data ' + '\033[1m' + '80/20: ' + '\033[0m', spam_test_avg_80_rf)
# Out:
# Average rf Training Accuracy for Spambase Data 20/80:  0.9595413278654292
# Average rf Training Accuracy for Spambase Data 50/50:  0.9434298436568503
# Average rf Training Accuracy for Spambase Data 80/20:  0.9372382682791368
#
# Average rf Validation Accuracy for Spambase Data 20/80:  0.9380434782608695
# Average rf Validation Accuracy for Spambase Data 50/50:  0.9297101449275362
# Average rf Validation Accuracy for Spambase Data 80/20:  0.9269927536231884
#
# Average rf Testing Accuracy for Spambase Data 20/80:  0.9224848320202842
# Average rf Testing Accuracy for Spambase Data 50/50:  0.9262639432130958
# Average rf Testing Accuracy for Spambase Data 80/20:  0.9308722403184944

# %%
# Online Shoppers Data
grid_search = GridSearchCV(clf, {"max_depth": [5], "max_features": [12]}, return_train_score = True, cv = 10, iid = True) # 10-fold.

print('\033[1m' + 'Online Shoppers Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 5, Best number of features: 12')
# shoppers 20/80 1st trial
grid_search.fit(shoppersX_train1_20, shoppersY_train1_20)
shoppers_train1_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_20_rf, ', Validation Accuracy: ', shoppers_val1_acc_20_rf)
shoppers_test1_acc_20_rf = sum(grid_search.best_estimator_.predict(shoppersX_test1_20) == shoppersY_test1_20) / len(shoppersX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_20_rf)

#shoppers 20/80 2nd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train2_20, shoppersY_train2_20)
shoppers_train2_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_20_rf, ', Validation Accuracy: ', shoppers_val2_acc_20_rf)
shoppers_test2_acc_20_rf = sum(grid_search.best_estimator_.predict(shoppersX_test2_20) == shoppersY_test2_20) / len(shoppersX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_20_rf)

#shoppers 20/80 3rd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train3_20, shoppersY_train3_20)
shoppers_train3_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_20_rf, ', Validation Accuracy: ', shoppers_val3_acc_20_rf)
shoppers_test3_acc_20_rf = sum(grid_search.best_estimator_.predict(shoppersX_test3_20) == shoppersY_test3_20) / len(shoppersX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_20_rf)

print()
print('Partition for 50/50')
# shoppers 50/50 1st trial
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train1_50, shoppersY_train1_50)
shoppers_train1_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_50_rf, ', Validation Accuracy: ', shoppers_val1_acc_50_rf)
shoppers_test1_acc_50_rf = sum(grid_search.best_estimator_.predict(shoppersX_test1_50) == shoppersY_test1_50) / len(shoppersX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_50_rf)

#shoppers 50/50 2nd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train2_50, shoppersY_train2_50)
shoppers_train2_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_50_rf, ', Validation Accuracy: ', shoppers_val2_acc_50_rf)
shoppers_test2_acc_50_rf = sum(grid_search.best_estimator_.predict(shoppersX_test2_50) == shoppersY_test2_50) / len(shoppersX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_50_rf)

#shoppers 50/50 3rd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train3_50, shoppersY_train3_50)
shoppers_train3_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_50_rf, ', Validation Accuracy: ', shoppers_val3_acc_50_rf)
shoppers_test3_acc_50_rf = sum(grid_search.best_estimator_.predict(shoppersX_test3_50) == shoppersY_test3_50) / len(shoppersX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_50_rf)

print()
print('Partition for 80/20')
# shoppers 80/20 1st trial
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train1_80, shoppersY_train1_80)
shoppers_train1_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val1_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train1_acc_80_rf, ', Validation Accuracy: ', shoppers_val1_acc_80_rf)
shoppers_test1_acc_80_rf = sum(grid_search.best_estimator_.predict(shoppersX_test1_80) == shoppersY_test1_80) / len(shoppersX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test1_acc_80_rf)

#shoppers 80/20 2nd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train2_80, shoppersY_train2_80)
shoppers_train2_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val2_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train2_acc_80_rf, ', Validation Accuracy: ', shoppers_val2_acc_80_rf)
shoppers_test2_acc_80_rf = sum(grid_search.best_estimator_.predict(shoppersX_test2_80) == shoppersY_test2_80) / len(shoppersX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test2_acc_80_rf)

#shoppers 80/20 3rd trial
print('---')
print('Best depth: 5, Best number of features: 12')
grid_search.fit(shoppersX_train3_80, shoppersY_train3_80)
shoppers_train3_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
shoppers_val3_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', shoppers_train3_acc_80_rf, ', Validation Accuracy: ', shoppers_val3_acc_80_rf)
shoppers_test3_acc_80_rf = sum(grid_search.best_estimator_.predict(shoppersX_test3_80) == shoppersY_test3_80) / len(shoppersX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', shoppers_test3_acc_80_rf)
# Out:
# Online Shoppers Data
# Partition for 20/80
# Best depth: 5, Best number of features: 12
# Training Accuracy:  0.9257449694960966 , Validation Accuracy:  0.8994322789943228
# Testing Accuracy:  0.9003446877534469
# ---
# Best depth: 5, Best number of features: 12
# Training Accuracy:  0.9284944260616491 , Validation Accuracy:  0.894566098945661
# Testing Accuracy:  0.9057177615571776
# ---
# Best depth: 5, Best number of features: 12
# Training Accuracy:  0.9296653390659699 , Validation Accuracy:  0.8986212489862125
# Testing Accuracy:  0.9014598540145985
#
# Partition for 50/50
# Best depth: 5, Best number of features: 12
# Training Accuracy:  0.9141746885566995 , Validation Accuracy:  0.8994322789943228
# Testing Accuracy:  0.9031630170316302
# ---
# Best depth: 5, Best number of features: 12
# Training Accuracy:  0.9162296201351028 , Validation Accuracy:  0.9021897810218978
# Testing Accuracy:  0.9077047850770479
# ---
# Best depth: 5, Best number of features: 12
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
shoppers_train_avg_20_rf = (shoppers_train1_acc_20_rf + shoppers_train2_acc_20_rf + shoppers_train3_acc_20_rf)/3
shoppers_train_avg_50_rf = (shoppers_train1_acc_50_rf + shoppers_train2_acc_50_rf + shoppers_train3_acc_50_rf)/3
shoppers_train_avg_80_rf = (shoppers_train1_acc_80_rf + shoppers_train2_acc_80_rf + shoppers_train3_acc_80_rf)/3

# Average validation accuracy
shoppers_val_avg_20_rf = (shoppers_val1_acc_20_rf + shoppers_val2_acc_20_rf + shoppers_val3_acc_20_rf)/3
shoppers_val_avg_50_rf = (shoppers_val1_acc_50_rf + shoppers_val2_acc_50_rf + shoppers_val3_acc_50_rf)/3
shoppers_val_avg_80_rf = (shoppers_val1_acc_80_rf + shoppers_val2_acc_80_rf + shoppers_val3_acc_80_rf)/3

# Average testing accuracy
shoppers_test_avg_20_rf = (shoppers_test1_acc_20_rf + shoppers_test2_acc_20_rf + shoppers_test3_acc_20_rf)/3
shoppers_test_avg_50_rf = (shoppers_test1_acc_50_rf + shoppers_test2_acc_50_rf + shoppers_test3_acc_50_rf)/3
shoppers_test_avg_80_rf = (shoppers_test1_acc_80_rf + shoppers_test2_acc_80_rf + shoppers_test3_acc_80_rf)/3

print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_train_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_train_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_train_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_val_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_val_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_val_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '20/80: ' + '\033[0m', shoppers_test_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '50/50: ' + '\033[0m', shoppers_test_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Online Shoppers Data ' + '\033[1m' + '80/20: ' + '\033[0m', shoppers_test_avg_80_rf)
# Out:
# Average rf Training Accuracy for Online Shoppers Data 20/80:  0.927968244874572
# Average rf Training Accuracy for Online Shoppers Data 50/50:  0.9163977370162907
# Average rf Training Accuracy for Online Shoppers Data 80/20:  0.9146240888818887
#
# Average rf Validation Accuracy for Online Shoppers Data 20/80:  0.8975398756420655
# Average rf Validation Accuracy for Online Shoppers Data 50/50:  0.9021897810218977
# Average rf Validation Accuracy for Online Shoppers Data 80/20:  0.9051094890510948
#
# Average rf Testing Accuracy for Online Shoppers Data 20/80:  0.9025074344417411
# Average rf Testing Accuracy for Online Shoppers Data 50/50:  0.9045688023790214
# Average rf Testing Accuracy for Online Shoppers Data 80/20:  0.9022708840227088

# %%
# Electric Grid Data

grid_search = GridSearchCV(clf, {"max_depth": [1], "max_features": [4]}, return_train_score = True, cv = 10, iid = True) # 10-fold.

print('\033[1m' + 'Electric Grid Data' + '\033[0m')
print('Partition for 20/80')
print('Best depth: 5, Best number of features: 4')
# elecgrid 20/80 1st trial
grid_search.fit(elecgridX_train1_20, elecgridY_train1_20)
elecgrid_train1_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_20_rf, ', Validation Accuracy: ', elecgrid_val1_acc_20_rf)
elecgrid_test1_acc_20_rf = sum(grid_search.best_estimator_.predict(elecgridX_test1_20) == elecgridY_test1_20) / len(elecgridX_test1_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_20_rf)

#elecgrid 20/80 2nd trial
print('---')
print('Best depth: 5, Best number of features: 4')
grid_search.fit(elecgridX_train2_20, elecgridY_train2_20)
elecgrid_train2_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_20_rf, ', Validation Accuracy: ', elecgrid_val2_acc_20_rf)
elecgrid_test2_acc_20_rf = sum(grid_search.best_estimator_.predict(elecgridX_test2_20) == elecgridY_test2_20) / len(elecgridX_test2_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_20_rf)

#elecgrid 20/80 3rd trial
print('---')
print('Best depth: 5, Best number of features: 4')
grid_search.fit(elecgridX_train3_20, elecgridY_train3_20)
elecgrid_train3_acc_20_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_20_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_20_rf, ', Validation Accuracy: ', elecgrid_val3_acc_20_rf)
elecgrid_test3_acc_20_rf = sum(grid_search.best_estimator_.predict(elecgridX_test3_20) == elecgridY_test3_20) / len(elecgridX_test3_20)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_20_rf)

print()
print('Partition for 50/50')
# elecgrid 50/50 1st trial
print('Best depth: 5, Best number of features: 4')
grid_search.fit(elecgridX_train1_50, elecgridY_train1_50)
elecgrid_train1_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_50_rf, ', Validation Accuracy: ', elecgrid_val1_acc_50_rf)
elecgrid_test1_acc_50_rf = sum(grid_search.best_estimator_.predict(elecgridX_test1_50) == elecgridY_test1_50) / len(elecgridX_test1_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_50_rf)

#elecgrid 50/50 2nd trial
print('---')
print('Best depth: 5, Best number of features: 6')
grid_search = GridSearchCV(clf, {"max_depth": [1], "max_features": [6]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train2_50, elecgridY_train2_50)
elecgrid_train2_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_50_rf, ', Validation Accuracy: ', elecgrid_val2_acc_50_rf)
elecgrid_test2_acc_50_rf = sum(grid_search.best_estimator_.predict(elecgridX_test2_50) == elecgridY_test2_50) / len(elecgridX_test2_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_50_rf)

#elecgrid 50/50 3rd trial
print('---')
print('Best depth: 5, Best number of features: 6')
grid_search.fit(elecgridX_train3_50, elecgridY_train3_50)
elecgrid_train3_acc_50_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_50_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_50_rf, ', Validation Accuracy: ', elecgrid_val3_acc_50_rf)
elecgrid_test3_acc_50_rf = sum(grid_search.best_estimator_.predict(elecgridX_test3_50) == elecgridY_test3_50) / len(elecgridX_test3_50)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_50_rf)

print()
print('Partition for 80/20')
# elecgrid 80/20 1st trial
print('Best depth: 5, Best number of features: 4')
grid_search = GridSearchCV(clf, {"max_depth": [1], "max_features": [4]}, return_train_score = True, cv = 10, iid = True) # 10-fold.
grid_search.fit(elecgridX_train1_80, elecgridY_train1_80)
elecgrid_train1_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val1_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train1_acc_80_rf, ', Validation Accuracy: ', elecgrid_val1_acc_80_rf)
elecgrid_test1_acc_80_rf = sum(grid_search.best_estimator_.predict(elecgridX_test1_80) == elecgridY_test1_80) / len(elecgridX_test1_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test1_acc_80_rf)

#elecgrid 80/20 2nd trial
print('---')
print('Best depth: 5, Best number of features: 4')
grid_search.fit(elecgridX_train2_80, elecgridY_train2_80)
elecgrid_train2_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val2_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train2_acc_80_rf, ', Validation Accuracy: ', elecgrid_val2_acc_80_rf)
elecgrid_test2_acc_80_rf = sum(grid_search.best_estimator_.predict(elecgridX_test2_80) == elecgridY_test2_80) / len(elecgridX_test2_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test2_acc_80_rf)

#elecgrid 80/20 3rd trial
print('---')
print('Best depth: 5, Best number of features: 4')
grid_search.fit(elecgridX_train3_80, elecgridY_train3_80)
elecgrid_train3_acc_80_rf = grid_search.cv_results_['mean_train_score'][0]
elecgrid_val3_acc_80_rf = grid_search.cv_results_['mean_test_score'][0]
print('Training Accuracy: ', elecgrid_train3_acc_80_rf, ', Validation Accuracy: ', elecgrid_val3_acc_80_rf)
elecgrid_test3_acc_80_rf = sum(grid_search.best_estimator_.predict(elecgridX_test3_80) == elecgridY_test3_80) / len(elecgridX_test3_80)
print('\033[1m' + 'Testing Accuracy: ' + '\033[0m', elecgrid_test3_acc_80_rf)
# Out:
# Electric Grid Data
# Partition for 20/80
# Best depth: 5, Best number of features: 4
# Training Accuracy:  0.9996110492798163 , Validation Accuracy:  0.9985
# Testing Accuracy:  0.999875
# ---
# Best depth: 5, Best number of features: 4
# Training Accuracy:  0.9998888888888888 , Validation Accuracy:  1.0
# Testing Accuracy:  0.9995
# ---
# Best depth: 5, Best number of features: 4
# Training Accuracy:  0.9999444444444444 , Validation Accuracy:  0.9995
# Testing Accuracy:  0.999375
#
# Partition for 50/50
# Best depth: 5, Best number of features: 4
# Training Accuracy:  0.9997999999978052 , Validation Accuracy:  0.9998
# Testing Accuracy:  0.9998
# ---
# Best depth: 5, Best number of features: 6
# Training Accuracy:  0.9998222222178326 , Validation Accuracy:  0.9998
# Testing Accuracy:  0.9998
# ---
# Best depth: 5, Best number of features: 6
# Training Accuracy:  1.0 , Validation Accuracy:  0.9996
# Testing Accuracy:  0.9998
#
# Partition for 80/20
# ...

# %%
# -- Accuracy Averages --
# Average training accuracy
elecgrid_train_avg_20_rf = (elecgrid_train1_acc_20_rf + elecgrid_train2_acc_20_rf + elecgrid_train3_acc_20_rf)/3
elecgrid_train_avg_50_rf = (elecgrid_train1_acc_50_rf + elecgrid_train2_acc_50_rf + elecgrid_train3_acc_50_rf)/3
elecgrid_train_avg_80_rf = (elecgrid_train1_acc_80_rf + elecgrid_train2_acc_80_rf + elecgrid_train3_acc_80_rf)/3

# Average validation accuracy
elecgrid_val_avg_20_rf = (elecgrid_val1_acc_20_rf + elecgrid_val2_acc_20_rf + elecgrid_val3_acc_20_rf)/3
elecgrid_val_avg_50_rf = (elecgrid_val1_acc_50_rf + elecgrid_val2_acc_50_rf + elecgrid_val3_acc_50_rf)/3
elecgrid_val_avg_80_rf = (elecgrid_val1_acc_80_rf + elecgrid_val2_acc_80_rf + elecgrid_val3_acc_80_rf)/3

# Average testing accuracy
elecgrid_test_avg_20_rf = (elecgrid_test1_acc_20_rf + elecgrid_test2_acc_20_rf + elecgrid_test3_acc_20_rf)/3
elecgrid_test_avg_50_rf = (elecgrid_test1_acc_50_rf + elecgrid_test2_acc_50_rf + elecgrid_test3_acc_50_rf)/3
elecgrid_test_avg_80_rf = (elecgrid_test1_acc_80_rf + elecgrid_test2_acc_80_rf + elecgrid_test3_acc_80_rf)/3

print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_train_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_train_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Training ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_train_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_val_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_val_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Validation ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_val_avg_80_rf)
print()

print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '20/80: ' + '\033[0m', elecgrid_test_avg_20_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '50/50: ' + '\033[0m', elecgrid_test_avg_50_rf)
print('Average rf ' + '\033[1m' + 'Testing ' + '\033[0m' + 'Accuracy for Electric Grid Data ' + '\033[1m' + '80/20: ' + '\033[0m', elecgrid_test_avg_80_rf)
# Out:
# Average rf Training Accuracy for Electric Grid Data 20/80:  0.9998147942043832
# Average rf Training Accuracy for Electric Grid Data 50/50:  0.9998740740718793
# Average rf Training Accuracy for Electric Grid Data 80/20:  0.9998888901736468
#
# Average rf Validation Accuracy for Electric Grid Data 20/80:  0.9993333333333334
# Average rf Validation Accuracy for Electric Grid Data 50/50:  0.9997333333333334
# Average rf Validation Accuracy for Electric Grid Data 80/20:  0.9997916666666667
#
# Average rf Testing Accuracy for Electric Grid Data 20/80:  0.9995833333333334
# Average rf Testing Accuracy for Electric Grid Data 50/50:  0.9998
# Average rf Testing Accuracy for Electric Grid Data 80/20:  1.0
